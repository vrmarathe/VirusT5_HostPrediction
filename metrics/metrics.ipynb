# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <h2>Influenza Metrics </h2>

# %%
df_influenza = pd.read_csv('host_13_epochs_metrics_influenza.csv')

# %%
df_influenza.head()
# Out:
#      loss  learning_rate  epoch  step  eval_loss  eval_accuracy  eval_runtime  \
# 0  0.3170       0.000020   0.15   500        NaN            NaN           NaN
# 1  0.0122       0.000020   0.31  1000        NaN            NaN           NaN
# 2  0.0109       0.000019   0.46  1500        NaN            NaN           NaN
# 3  0.0092       0.000019   0.61  2000        NaN            NaN           NaN
# 4  0.0096       0.000019   0.77  2500        NaN            NaN           NaN
#
#    eval_samples_per_second  eval_steps_per_second  train_runtime  \
# 0                      NaN                    NaN            NaN
# 1                      NaN                    NaN            NaN
# 2                      NaN                    NaN            NaN
# 3                      NaN                    NaN            NaN
# 4                      NaN                    NaN            NaN
#
#    train_samples_per_second  train_steps_per_second  total_flos  train_loss
# ...

# %% [markdown]
# <h2> Influenza Loss Graphs

# %%
# Load the dataset

epochs = df_influenza['epoch']
loss = df_influenza['loss']
eval_loss = df_influenza['eval_loss']

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))  # Slightly larger for better clarity

# Configure Fonts for Compatibility
plt.rcParams['font.family'] = 'Arial'

# Plotting training loss with colorblind-friendly color
line1, = ax.plot(
    epochs[~np.isnan(loss)], 
    loss[~np.isnan(loss)], 
    label='Training Loss', 
    color='#0072B2',  # Dark blue
    linewidth=2  # Increased line width for clarity
)

# Plotting evaluation loss with colorblind-friendly color
line2, = ax.plot(
    epochs[~np.isnan(eval_loss)], 
    eval_loss[~np.isnan(eval_loss)], 
    label='Evaluation Loss', 
    color='#E69F00',  # Dark orange
    linestyle='--',  # Differentiated style
    linewidth=2
)

# Add grid for readability
ax.grid(visible=True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# Add labels, title, and legend
ax.set_xlabel('Epochs', fontsize=14, labelpad=10)  # Adjusted padding for clarity
ax.set_ylabel('Loss', fontsize=14, labelpad=10)
ax.set_title('Training and Evaluation Loss For Influenza Host Classification', fontsize=16, pad=15)  # Increased title size and padding
ax.tick_params(axis='both', labelsize=12)

# Set y-axis limits for better comparison
ax.set_ylim([0, max(max(loss), max(eval_loss)) * 1.1])  # 10% buffer for clarity

# Legend improvements
ax.legend(
    loc='upper right', 
    fontsize=12, 
    frameon=True, 
    shadow=True, 
    borderpad=1, 
    edgecolor='black'
)

# Save the figure in publication-ready formats
output_filename_base = "Fig2"
# plt.savefig(f"{output_filename_base}.png", dpi=1200, format='png', bbox_inches='tight')  # High-quality raster
# plt.savefig(f"{output_filename_base}.tif", dpi=1200, format='tiff', bbox_inches='tight')  # High-quality raster
# plt.savefig(f"{output_filename_base}.eps", dpi=1200,format='eps', bbox_inches='tight')          # High-quality vector
# plt.savefig(f"{output_filename_base}.svg",dpi=1200,format='svg', bbox_inches='tight')   # High-quality vector
# # Save in vector format (preferred for journal)
# plt.savefig("Fig2.pdf", format="pdf", bbox_inches="tight",dpi=1200)

# # Save as high-resolution raster image (600 dpi for line art)
# plt.savefig("Fig2.tiff", format="tiff", dpi=1200, bbox_inches="tight")

# Show plot
plt.show()

# %%
decodedLabels=['hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'gs', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'gs', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'dck', 'hman', 'hman', 'hman', 'hman', 'chckn', 'dck', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'swn', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'swn', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'dck', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'gs', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'gs', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn']

# %%
decodedPreds=['hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'trky', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'chckn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'gs', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'swn', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'swn', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'dck', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'dck', 'hman', 'gs', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'dck', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'gs', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'trky', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'gs', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'chckn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'swn', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman', 'hman']

# %%
hostClasses=['chicken', 'duck', 'goose', 'human', 'swine', 'turkey']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(decodedLabels, decodedPreds)

# Set figure size
fig, ax = plt.subplots(figsize=(6, 5))  # Adjust size for readability

# Use a colorblind-friendly colormap (e.g., 'cividis' or 'viridis')
sns.heatmap(
    conf_matrix, 
    annot=True, 
    fmt='d', 
    xticklabels=hostClasses, 
    yticklabels=hostClasses, 
    cmap='cividis',  # Colorblind-friendly colormap
    linewidths=0.5,  # Adds separation lines between cells
    linecolor="gray",
    cbar_kws={'label': 'Count'}  # Add color bar label
)

# Rotate labels for clarity
plt.xticks(rotation=45, ha="right", fontsize=12)
plt.yticks(rotation=45, fontsize=12)

# Axis labels and title
plt.xlabel("Predicted Label", fontsize=14, fontweight="bold")
plt.ylabel("True Label", fontsize=14, fontweight="bold")
plt.title("Confusion Matrix for Influenza Host Classification", fontsize=16, fontweight="bold")

# # Save in vector format (preferred for journal)
# plt.savefig("Fig1.pdf", format="pdf", bbox_inches="tight",dpi=900)

# # Save as high-resolution raster image (600 dpi for line art)
# plt.savefig("Fig1.tiff", format="tiff", dpi=900, bbox_inches="tight")

# Show the plot
plt.show()

# %%
df_flavi=pd.read_csv("host_15_epochs_metrics_flavi.csv")

# %%
# Load the dataset

epochs = df_flavi['epoch']
loss = df_flavi['loss']
eval_loss = df_flavi['eval_loss']

# Set up the figure and axis
fig, ax = plt.subplots(figsize=(12, 6))  # Slightly larger for better clarity

# Configure Fonts for Compatibility
plt.rcParams['font.family'] = 'Arial'

# Plotting training loss with colorblind-friendly color
line1, = ax.plot(
    epochs[~np.isnan(loss)], 
    loss[~np.isnan(loss)], 
    label='Training Loss', 
    color='#0072B2',  # Dark blue
    linewidth=2  # Increased line width for clarity
)

# Plotting evaluation loss with colorblind-friendly color
line2, = ax.plot(
    epochs[~np.isnan(eval_loss)], 
    eval_loss[~np.isnan(eval_loss)], 
    label='Evaluation Loss', 
    color='#E69F00',  # Dark orange
    linestyle='--',  # Differentiated style
    linewidth=2
)

# Add grid for readability
ax.grid(visible=True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# Add labels, title, and legend
ax.set_xlabel('Epochs', fontsize=14, labelpad=10)  # Adjusted padding for clarity
ax.set_ylabel('Loss', fontsize=14, labelpad=10)
ax.set_title('Training and Evaluation Loss For Flavivirus Host Classification', fontsize=16, pad=15)  # Increased title size and padding
ax.tick_params(axis='both', labelsize=12)

# Set y-axis limits for better comparison
ax.set_ylim([0, max(max(loss), max(eval_loss)) * 1.1])  # 10% buffer for clarity

# Legend improvements
ax.legend(
    loc='upper right', 
    fontsize=12, 
    frameon=True, 
    shadow=True, 
    borderpad=1, 
    edgecolor='black'
)

# Save the figure in publication-ready formats
output_filename_base = "Fig4"
# plt.savefig(f"{output_filename_base}.png", dpi=1200, format='png', bbox_inches='tight')  # High-quality raster
# plt.savefig(f"{output_filename_base}.tif", dpi=1200, format='tiff', bbox_inches='tight')  # High-quality raster
# plt.savefig(f"{output_filename_base}.eps", dpi=1200,format='eps', bbox_inches='tight')          # High-quality vector
# plt.savefig(f"{output_filename_base}.svg",dpi=1200,format='svg', bbox_inches='tight')   # High-quality vector
# # Save in vector format (preferred for journal)
# plt.savefig("Fig4.pdf", format="pdf", bbox_inches="tight",dpi=1200)

# # Save as high-resolution raster image (600 dpi for line art)
# plt.savefig("Fig4.tiff", format="tiff", dpi=1200, bbox_inches="tight")

# Show plot
plt.show()

# %%
y_pred=['ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ds', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ds', 'ds', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ds', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ds', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ads', 'c', 'ds', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'ads', 'c', 'ds', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads'] 
y=['ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ds', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ds', 'ds', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ds', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ds', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ds', 'ads', 'c', 'ds', 'ads', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'ads', 'ds', 'c', 'c', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'c', 'ads', 'ads', 'c', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ds', 'ads', 'c', 'ads', 'ds', 'ads', 'ads', 'c', 'c', 'c', 'ads', 'c', 'c', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'c', 'ds', 'ads', 'c', 'ds', 'ads', 'ds', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'c', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'c', 'ads', 'ads', 'ads', 'ads', 'ads', 'ads']

# %%
flavi_hostClasses=["aedes","culex","ixodes"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix

# Compute confusion matrix
conf_matrix = confusion_matrix(y, y_pred)

# Set figure size
fig, ax = plt.subplots(figsize=(6, 5))  # Adjust size for readability

# Use a colorblind-friendly colormap (e.g., 'cividis' or 'viridis')
sns.heatmap(
    conf_matrix, 
    annot=True, 
    fmt='d', 
    xticklabels=flavi_hostClasses, 
    yticklabels=flavi_hostClasses, 
    cmap='cividis',  # Colorblind-friendly colormap
    linewidths=0.5,  # Adds separation lines between cells
    linecolor="gray",
    cbar_kws={'label': 'Count'}  # Add color bar label
)

# Rotate labels for clarity
plt.xticks(rotation=45, ha="right", fontsize=12)
plt.yticks(rotation=45, fontsize=12)

# Axis labels and title
plt.xlabel("Predicted Label", fontsize=14, fontweight="bold")
plt.ylabel("True Label", fontsize=14, fontweight="bold")
plt.title("Confusion Matrix for Flavivirus Host Classification", fontsize=16, fontweight="bold")

# Save in vector format (preferred for journal)
#plt.savefig("Fig3.pdf", format="pdf", bbox_inches="tight",dpi=1200)

# Save as high-resolution raster image (600 dpi for line art)
#plt.savefig("Fig3.tiff", format="tiff", dpi=1200, bbox_inches="tight")

# Show the plot
plt.show()
